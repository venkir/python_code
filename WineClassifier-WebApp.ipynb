# %% [markdown]
# ## PyCaret and Streamlit: Create and Deploy Wine Classifier Web App
#
# Originally appeared in medium article by: Ruben Winastwan. The article can be found here at
# ```https://towardsdatascience.com/pycaret-and-streamlit-how-to-create-and-deploy-data-science-web-app-273d205271a3```

# %% [markdown]
# ### Modified by: Venki Ramachandran as part of his Data Science Practise

# %%
import pandas as pd
import numpy as np

# %%
# Load the data set
wine_df = pd.read_csv("winequality-red.csv")

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# What is the range of the quality column?
wine_df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
# Is equal to and above 6 a good wine? Let us categorize it that way
# Change t he value in 'quality' to 'good' or 'bad' based on quality value
wine_df.quality = np.where(wine_df.quality >= 6,'Good', 'Bad')

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     Bad
# 1      9.8     Bad
# 2      9.8     Bad
# 3      9.8    Good
# 4      9.4     Bad

# %% [markdown]
# ### Load PyCaret using the Terminal or the iTerm window
#
# ```pip install pycaret```
#
# <img src="./PyCaret-Install-MacOs.png">
#
# Check and see if you get the above success message after install.
#
# PyCaret is AWESOME...it is a low-code machine learning library that automates all of the machine learning workflows. What it does is that it provides a wrapper for popular machine learning libraries such as scikit-learn, XGBoost, LightGBM, CatBoost, and many more

# %%
# Step1: setup the environment
from pycaret.classification import *
exp_clf01 = setup(data = wine_df, target = 'quality', session_id = 123)
# Out:
# <style  type="text/css" >
# </style><table id="T_69556ab4_b2f0_11eb_bfd6_faffc252199c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow1_col1" class="data row1 col1" >quality</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow3_col1" class="data row3 col1" >Bad: 0, Good: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow4_col1" class="data row4 col1" >(1599, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_69556ab4_b2f0_11eb_bfd6_faffc252199crow6_col1" class="data row6 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_69556ab4_b2f0_11eb_bfd6_faffc252199clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T
('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# 2021-05-12 12:35:19.419 INFO    logs: setup() succesfully completed......................................

# %% [markdown]
# We passed the following parameters:
#
#     * data — Our input data.
#     * target — The name of the feature that we want to predict (dependent variable).
#     * session_id — The identifier for our setup environment.

# %% [markdown]
# You need to take a look at the output carefully because there are times when the function infers the data types incorrectly. If you find that one of the feature is inferred incorrectly, you can correct it by doing the following:
#
# ```exp_clf01 = setup(data = wine_df, target = 'quality', session_id = 123, categorical_features = ['feature1', 'feature2'], numerical_features = ['feature3', 'feature4'])```

# %% [markdown]
# You can use categorical_features or numerical_features parameter to change the data types that are incorrectly inferred by setup() function

# %%
# Building a machine learning model
# With PyCaret, you’re able to compare the performance of 
# different kinds of classification models with literally single line of code
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_76295462_b2f0_11eb_bfd6_faffc252199c th {
#           text-align: left;
#     }#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col0,#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col2,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col0,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col1,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col3,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col4,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col5,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col6,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col7,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col0,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col1,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col2,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col3,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col4,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col5,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col6,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col7,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col0,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col1,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col2,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col3,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col4,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col5,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col6,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col7,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col0,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col1,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col2,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col3,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col4,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col5,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col6,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col7,#T_76295462_b2f0_11eb_bfd6_faffc252199
#             text-align:  left;
#             text-align:  left;
#         }#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col1,#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col3,#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col4,#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col5,#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col6,#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col7,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col2{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow1_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow2_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow3_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow4_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow5_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow6_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow10_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow12_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_76295462_b2f0_11eb_bfd6_faffc252199crow7_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow8_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow9_col8,#T_76295462_b2f0_11eb_bfd6_faffc252199crow11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_76295462_b2f0_11eb_bfd6_faffc252199c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76295462_b2f0_11eb_bfd6_faffc252199clevel0_row0" class="row_heading level0 row0" >rf</th>
#                         <td id="T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col0" class="data row0 col0" >Random Forest Classifier</td>
#                         <td id="T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col1" class="data row0 col1" >0.8222</td>
#                         <td id="T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col2" class="data row0 col2" >0.8973</td>
#                         <td id="T_76295462_b2f0_11eb_bfd6_faffc252199crow0_col3" cla
# 2021-05-12 12:35:40.933 INFO    logs: create_model_container: 14
# 2021-05-12 12:35:40.934 INFO    logs: master_model_container: 14
# 2021-05-12 12:35:40.934 INFO    logs: display_container: 2
# 2021-05-12 12:35:40.936 INFO    logs: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)
# 2021-05-12 12:35:40.936 INFO    logs: compare_models() succesfully completed......................................

# %% [markdown]
# ### Experiment 2: Tuned Setup
# Before we go further, let’s see whether we can improve the performance of the models by tuning our setup() function.

# %%
exp_clf102 = setup(data = wine_df, target = 'quality',session_id=123, normalize = True, transformation = True)
# Out:
# <style  type="text/css" >
# #T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow29_col1,#T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow31_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T
_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199clevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_b4fbfb56_b2a8_11eb_bfd6_faffc252199crow18_col0" class="data row18 col0" >Use GPU</td>

# %%
# Let us try the best command again
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_dbff3cd6_b2a8_11eb_bfd6_faffc252199c th {
#           text-align: left;
#     }#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col0,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col4,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col7,#T_dbff3cd6_b2a8_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col1,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col2,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col3,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col5,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col6,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col7,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow1_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow2_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow3_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow4_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow5_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow7_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow8_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow9_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow10_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow11_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow12_col8,#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow6_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_dbff3cd6_b2a8_11eb_bfd6_faffc252199c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbff3cd6_b2a8_11eb_bfd6_faffc252199clevel0_row0" class="row_heading level0 row0" >et</th>
#                         <td id="T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col1" class="data row0 col1" >0.8231</td>
#                         <td id="T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col2" class="data row0 col2" >0.9032</td>
#                         <td id="T_dbff3cd6_b2a8_11eb_bfd6_faffc252199crow0_col3" class

# %% [markdown]
# ### Normalize and Transform the features
# We passed several additional parameters there to tune our setup:
#
#     * normalize — To transform our features by scaling them to a given range.
#     * transformation — To transform our features such that our data can be represented by  a normal distribution. This can be helpful for models like Logistic Regression, LDA, or Gaussian Native Bayes.
#
# Also note that we use the same session_id as our previous setup() function. This is to make sure that all of the future improvements on the model are solely due to the change that we’ve implemented in this setup() function.
#
# As you can see, most of the metrics are slightly improved after we tuned the setup. Before we tuned the setup, the F1 score of Extra Tree classifier is 0.8306. After we tuned the setup, the F1 score becomes 0.8375.

# %%
# Based on this result, let’s build our Extra Tree classifier. We can do this with a single line of code
et_model = create_model('et')
# Out:
# <style  type="text/css" >
# #T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col0,#T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col1,#T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col2,#T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col3,#T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col4,#T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col5,#T_565894a0_b2a9_11eb_bfd6_faffc252199crow10_col6{
#             background:  yellow;
#         }</style><table id="T_565894a0_b2a9_11eb_bfd6_faffc252199c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col0" class="data row0 col0" >0.8304</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col1" class="data row0 col1" >0.9087</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col2" class="data row0 col2" >0.7869</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col3" class="data row0 col3" >0.8889</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col4" class="data row0 col4" >0.8348</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col5" class="data row0 col5" >0.6618</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow0_col6" class="data row0 col6" >0.6670</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col0" class="data row1 col0" >0.8214</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col1" class="data row1 col1" >0.9182</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col2" class="data row1 col2" >0.8361</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col3" class="data row1 col3" >0.8361</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col4" class="data row1 col4" >0.8361</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col5" class="data row1 col5" >0.6400</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow1_col6" class="data row1 col6" >0.6400</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col0" class="data row2 col0" >0.8482</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col1" class="data row2 col1" >0.9346</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col2" class="data row2 col2" >0.8525</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col3" class="data row2 col3" >0.8667</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col4" class="data row2 col4" >0.8595</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col5" class="data row2 col5" >0.6945</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow2_col6" class="data row2 col6" >0.6946</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col0" class="data row3 col0" >0.8393</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col1" class="data row3 col1" >0.9039</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col2" class="data row3 col2" >0.8689</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col3" class="data row3 col3" >0.8413</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col4" class="data row3 col4" >0.8548</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col5" class="data row3 col5" >0.6749</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow3_col6" class="data row3 col6" >0.6754</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col0" class="data row4 col0" >0.8393</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col1" class="data row4 col1" >0.8941</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col2" class="data row4 col2" >0.8852</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col3" class="data row4 col3" >0.8308</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col4" class="data row4 col4" >0.8571</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col5" class="data row4 col5" >0.6739</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow4_col6" class="data row4 col6" >0.6757</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col0" class="data row5 col0" >0.8482</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col1" class="data row5 col1" >0.9261</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col2" class="data row5 col2" >0.8525</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col3" class="data row5 col3" >0.8667</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col4" class="data row5 col4" >0.8595</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col5" class="data row5 col5" >0.6945</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow5_col6" class="data row5 col6" >0.6946</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col0" class="data row6 col0" >0.8214</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col1" class="data row6 col1" >0.8987</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col2" class="data row6 col2" >0.8689</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col3" class="data row6 col3" >0.8154</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col4" class="data row6 col4" >0.8413</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col5" class="data row6 col5" >0.6377</td>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow6_col6" class="data row6 col6" >0.6393</td>
#             </tr>
#             <tr>
#                         <th id="T_565894a0_b2a9_11eb_bfd6_faffc252199clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_565894a0_b2a9_11eb_bfd6_faffc252199crow7_co

# %%
# Next, you can evaluate your model by looking at the visualization of the ROC curve, 
# feature importance, or confusion matrix of your model.
evaluate_model(et_model)

# Click on each of the buttons on the Plot Type and see the magic
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# We can now use our ```Extra Tree classifier``` to predict the test data that has been generated by PyCaret. As mentioned earlier, soon after we executed the setup() function at the very first step, PyCaret will automatically split our data into training data and test data. All of the model performance and evaluation metrics that we’ve seen above are solely based on the training data.
#
# To use the model to predict the test data, we can use the predict_model function

# %%
predict_model(et_model)
# Out:
# <style  type="text/css" >
# </style><table id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col1" class="data row0 col1" >0.7875</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col2" class="data row0 col2" >0.8858</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col3" class="data row0 col3" >0.8387</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col4" class="data row0 col4" >0.7704</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col5" class="data row0 col5" >0.8031</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col6" class="data row0 col6" >0.5732</td>
#                         <td id="T_cf0a1914_b2a9_11eb_bfd6_faffc252199crow0_col7" class="data row0 col7" >0.5757</td>
#             </tr>
#     </tbody></table>
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         1.020588         -0.262337     0.879940        0.909526  -0.811347
# 1         0.803912          0.365825     0.069809        0.182406   0.169895
# 2        -0.548070          1.883447    -0.893328       -0.877415  -0.243956
# 3         0.107601         -1.862275     0.790650       -0.626787  -0.545447
# 4        -0.094336         -0.848967    -0.143101       -0.877415  -0.079076
# ..             ...               ...          ...             ...        ...
# 475      -0.548070         -0.140215     0.322042       -0.184964  -1.025574
# 476       1.829642         -0.021461     1.097954        0.007663   0.466399
# 477      -0.629806         -0.781026     0.222889       -0.877415  -0.301560
# 478       0.936346         -1.341807     0.654205       -1.148794  -1.025574
# 479       0.170983          0.520056    -0.035430        0.007663   1.252116
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0              -1.539989             -1.767543 -0.001569  0.179457  -0.026319
# 1               0.853181              1.990040  0.562903 -0.216540  -0.678448
# 2               0.626979              0.590835 -0.012134  0.309834  -0.576033
# 3              -0.666601             -1.164981 -1.619909 -0.619242  -0.783892
# 4               0.853181              0.377180 -0.235514 -0.150025   0.344294
# ..                   ...                   ...       ...       ...        ...
# 475             1.330936              0.533354  0.282229 -0.017589   0.205814
# 476            -1.351598             -1.357751  1.774647 -0.754683  -2.001079
# 477             1.330936              0.934478  0.056549  0.761128  -0.287161
# 478            -1.735120             -1.697007 -1.047378 -1.095523  -0.476666
# 479            -0.666601             -0.045372 -0.310424 -1.027116  -0.892347
#
#       alcohol quality Label  Score
# 0    1.507669    Good  Good   0.88
# 1   -1.071227     Bad   Bad   0.95
# 2   -1.403862     Bad   Bad   0.79
# 3    1.558527    Good  Good   0.85
# 4   -1.234888     Bad   Bad   0.62
# ..        ...     ...   ...    ...
# 475 -0.205689    Good  Good   1.00
# 476 -0.760163     Bad   Bad   1.00
# 477 -0.912956    Good  Good   1.00
# 478  1.112170    Good  Good   0.90
# 479 -0.471378     Bad   Bad   1.00
#
# [480 rows x 14 columns]

# %% [markdown]
# ### Test Data
#
# Make sure that the number of rows above = 480 which is the rows in the test data when PyCaret automatically split it into train and test data set.

# %%
# Let us save the model
save_model(et_model, model_name = 'extra_tree_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='quality',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators=100, n_jobs=-1,
#                                        oob_score=False, random_state=123,
#                                        verbose=0, warm_start=False)]],
#           verbose=False),
#  'extra_tree_model.pkl')

# %% [markdown]
# ## Build the Web App with Streamlit
#
# Now it’s time for us to build our wine classifier web app. In this post, we’re going to use Streamlit to build the web app as it is more beginner friendly than Flask.
#
# ```pip install streamlit```
#
# <img src="./streamlit_install.png">

# %% [markdown]
# The first thing that we need to do is importing all of the relevant libraries. Note that we’re going to use the Extra Tree classifier model that we’ve saved before using PyCaret. To load the model and to make a prediction using the saved model, we can use load_model and predict_model functions from PyCaret

# %%
# Create a new .py script in the same location and copy this code.
# Load the libraries and set the landing page

from pycaret.classification import load_model, predict_model
import streamlit as st
import pandas as pd
import numpy as np


def predict_quality(model, df):
    
    predictions_data = predict_model(estimator = model, data = df)
    return predictions_data['Label'][0]
    
model = load_model('extra_tree_model')


st.title('Wine Quality Classifier Web App')
st.subheader('Life is too short to drink Bad Wine - Old Jungle Saying!!')
st.write(
    "This is a web app to classify the quality of your wine based on\n"
    "several features that you can see in the sidebar. Please adjust the\n"
    "value of each feature. After that, click on the Predict button at the bottom to\n"
    "see the prediction of the classifier.\n\n"
    "Coding details originally appreared in medium article by Ruben Winastwan, All credit goes to him.\n\n"
    "Modified By: Venki Ramachandran on 12-May-2021."
)
# Out:
# 2021-05-12 12:34:33.678 INFO    logs: Initializing load_model()
# 2021-05-12 12:34:33.679 INFO    logs: load_model(model_name=extra_tree_model, platform=None, authentication=None, verbose=True)
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# Next, we need to let the user to specify the value of our features. Since our features are all numeric features, it will be best to represent them with a slider widget. To create a slider widget, we can use slider() function from Streamlit

# %%
# Allow the user to select new features for prediction
fixed_acidity = st.sidebar.slider(label = 'Fixed Acidity', min_value = 4.0,
                          max_value = 16.0 ,
                          value = 10.0,
                          step = 0.1)

volatile_acidity = st.sidebar.slider(label = 'Volatile Acidity', min_value = 0.00,
                          max_value = 2.00 ,
                          value = 1.00,
                          step = 0.01)
                          
citric_acid = st.sidebar.slider(label = 'Citric Acid', min_value = 0.00,
                          max_value = 1.00 ,
                          value = 0.50,
                          step = 0.01)                          

residual_sugar = st.sidebar.slider(label = 'Residual Sugar', min_value = 0.0,
                          max_value = 16.0 ,
                          value = 8.0,
                          step = 0.1)

chlorides = st.sidebar.slider(label = 'Chlorides', min_value = 0.000,
                          max_value = 1.000 ,
                          value = 0.500,
                          step = 0.001)
   
f_sulf_diox = st.sidebar.slider(label = 'Free Sulfur Dioxide', min_value = 1,
                          max_value = 72,
                          value = 36,
                          step = 1)

t_sulf_diox = st.sidebar.slider(label = 'Total Sulfur Dioxide', min_value = 6,
                          max_value = 289 ,
                          value = 144,
                          step = 1)

density = st.sidebar.slider(label = 'Density', min_value = 0.0000,
                          max_value = 2.0000 ,
                          value = 0.9900,
                          step = 0.0001)

ph = st.sidebar.slider(label = 'pH', min_value = 2.00,
                          max_value = 5.00 ,
                          value = 3.00,
                          step = 0.01)
                          
sulphates = st.sidebar.slider(label = 'Sulphates', min_value = 0.00,
                          max_value = 2.00,
                          value = 0.50,
                          step = 0.01)

alcohol = st.sidebar.slider(label = 'Alcohol', min_value = 8.0,
                          max_value = 15.0,
                          value = 10.5,
                          step = 0.1)

# %% [markdown]
# Next we need to convert all of those user input values into a dataframe. Then, we can use the dataframe as the input of our model’s prediction

# %%
features = {'fixed acidity': fixed_acidity, 'volatile acidity': volatile_acidity,
            'citric acid': citric_acid, 'residual sugar': residual_sugar,
            'chlorides': chlorides, 'free sulfur dioxide': f_sulf_diox,
            'total sulfur dioxide': t_sulf_diox, 'density': density,
            'pH': ph, 'sulphates': sulphates, 'alcohol': alcohol
            }
 

features_df  = pd.DataFrame([features])

st.table(features_df)  

if st.button('Predict'):
    
    prediction = predict_quality(model, features_df)
    
    st.write(' Based on feature values, your wine quality is '+ str(prediction))

# %% [markdown]
# ### Deployment to localhost (your PC)
# To check your web app, you need to open your prompt, then go to the working directory of your Python file.
# In the working directory of your Python file, type the following:
#
# ```streamlit run app.py```
#
# Run the above command without the & as you have to answer some prompts. wait until you see
#
# <img src="./streamlit_deploy_success.png">
#
# Automatically opens the http://localhost:8501 in your default browser. It should look like the below screen:
#
# <img src="./localhost_landing_page.png">

# %% [markdown]
# ### Deploying on streamli.io to share with the world
#
# Please check out the public site at : https://share.streamlit.io/venkir/wine-classifier/main/app.py
